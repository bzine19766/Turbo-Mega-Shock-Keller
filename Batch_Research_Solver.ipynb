# %%
import pickle
import random
import time
import math
import os
from datetime import datetime
from typing import List, Tuple

class Keller5ResearchBatch:
    DIMENSION = 5
    TARGET_SIZE = 28
    
    def __init__(self):
        filename = f'keller_codes_d{self.DIMENSION}.data'
        print(f"Loading Keller5 data from {filename}...")
        with open(filename, 'rb') as f:
            self.codes_int = pickle.load(f)
        
        self.n = len(self.codes_int)
        self.best_clique = []
        self.best_size = 0
        self.current_seed = 0
        
        # Create statistics directory immediately
        if not os.path.exists("statistics"):
            os.makedirs("statistics")

    def are_neighbors(self, u: int, v: int) -> bool:
        if u == v: return False
        a, b = (u, v) if u < v else (v, u)
        return ((self.codes_int[a] >> b) & 1) == 0

    def get_all_neighbors(self, v: int) -> List[int]:
        return [u for u in range(self.n) if self.are_neighbors(v, u)]

    def vertex_conflict(self, v: int, vertices: List[int]) -> int:
        return sum(1 for u in vertices if u != v and not self.are_neighbors(v, u))

    def compute_conflict(self, vertices: List[int]) -> int:
        conflicts = 0
        for i in range(len(vertices)):
            for j in range(i + 1, len(vertices)):
                if not self.are_neighbors(vertices[i], vertices[j]):
                    conflicts += 1
        return conflicts

    def improve_with_sa(self, vertices: List[int], iterations: int, initial_temp: float, cooling_rate: float) -> Tuple[List[int], int]:
        current = vertices.copy()
        current_conflict = self.compute_conflict(current)
        best = current.copy()
        best_conflict = current_conflict
        temperature = initial_temp
        stagnant_counter = 0
        last_best_conflict = current_conflict

        for iteration in range(iterations):
            # Stochastic selection with exponential weighting
            v_confs = [self.vertex_conflict(v, current) for v in current]
            weights = [math.exp(c) for c in v_confs]
            worst_idx = random.choices(range(len(current)), weights=weights, k=1)[0]
            
            temp_set = current[:worst_idx] + current[worst_idx+1:]
            
            # Sampling candidates
            sample_size = 500 if len(current) >= 26 else 300
            candidates = random.sample(range(self.n), min(sample_size, self.n))
            
            best_replacement = -1
            min_conflicts = float('inf')
            for v in candidates:
                if v in temp_set: continue
                conf = self.vertex_conflict(v, temp_set)
                if conf < min_conflicts:
                    min_conflicts, best_replacement = conf, v
                if conf == 0: break
            
            if best_replacement == -1: continue
            
            new_vertices = temp_set + [best_replacement]
            new_conflict = self.compute_conflict(new_vertices)
            delta = new_conflict - current_conflict
            
            if delta <= 0 or (temperature > 1e-8 and random.random() < math.exp(-delta / temperature)):
                current, current_conflict = new_vertices, new_conflict
                if current_conflict < best_conflict:
                    best, best_conflict = current.copy(), current_conflict
            
            # Reheating logic
            if best_conflict == last_best_conflict: stagnant_counter += 1
            else: stagnant_counter, last_best_conflict = 0, best_conflict
            
            if stagnant_counter > 1500:
                temperature = max(temperature, initial_temp * 0.4)
                stagnant_counter = 0

            temperature *= cooling_rate
            if best_conflict == 0: break
        return best, best_conflict

    def save_to_statistics(self, clique: List[int], seed: int, duration: float):
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        size = len(clique)
        filename = f"statistics/k5_sz{size}_{timestamp}_seed{seed}.txt"
        
        with open(filename, "w", encoding="utf-8") as f:
            f.write(f"KELLER 5 RESEARCH REPORT\nID: {timestamp}\nSeed: {seed}\nTime: {duration:.2f}s\nSize: {size}\n")
            f.write("-" * 50 + "\nVertices: " + str(sorted(clique)) + "\n" + "-" * 50 + "\n")
            c_set = set(clique)
            for i, v in enumerate(sorted(clique)):
                all_neighbors = self.get_all_neighbors(v)
                f.write(f"Vertex {i+1:2d}: ID {v:4d} | Neighbors in clique: {len([n for n in all_neighbors if n in c_set])}\n")
        return filename

    def run_batch(self, num_runs: int):
        print(f"\n🚀 STARTING RESEARCH BATCH: {num_runs} RUNS")
        batch_start = time.time()
        successful_files = []

        for i in range(num_runs):
            run_start = time.time()
            self.current_seed = int(time.time() * 1000) % 2**32
            random.seed(self.current_seed)
            self.best_clique = []
            self.best_size = 0
            
            print(f"\n[Run {i+1}/{num_runs}] Seed: {self.current_seed}")
            
            # Define Phases
            phases = [("Early", 24, 8000, 20.0, 0.9996), 
                      ("Bridge", 26, 15000, 30.0, 0.9999), 
                      ("Final", 28, 45000, 65.0, 0.99999)]
            
            for name, target, iterations, temp, cooling in phases:
                initial = self.best_clique.copy()
                while len(initial) < target:
                    v = random.randint(0, self.n - 1)
                    if v not in initial: initial.append(v)
                
                improved, conf = self.improve_with_sa(initial, iterations, temp, cooling)
                if conf == 0:
                    self.best_size = len(improved)
                    self.best_clique = improved
                    if self.best_size >= target: continue

            run_duration = time.time() - run_start
            if len(self.best_clique) >= 28:
                fname = self.save_to_statistics(self.best_clique, self.current_seed, run_duration)
                successful_files.append(fname)
                print(f"✅ Success! Clique size 28 found in {run_duration:.2f}s")
            else:
                print(f"❌ Failed to reach 28 in this run.")

        print("\n" + "="*60)
        print(f"BATCH COMPLETE: {len(successful_files)}/{num_runs} SUCCESSFUL")
        print(f"Total Time: {time.time() - batch_start:.2f}s")
        print(f"Files saved in /statistics/ folder.")
        print("="*60)

if __name__ == "__main__":
    n = int(input("Enter number of runs to perform (e.g., 1, 10, 100): "))
    solver = Keller5ResearchBatch()
    solver.run_batch(n)
# Out:
# Enter number of runs to perform (e.g., 1, 10, 100):  100
# Loading Keller5 data from keller_codes_d5.data...
#
# 🚀 STARTING RESEARCH BATCH: 100 RUNS
#
# [Run 1/100] Seed: 1204383864
# ✅ Success! Clique size 28 found in 6.08s
#
# [Run 2/100] Seed: 1204389964
# ✅ Success! Clique size 28 found in 42.00s
#
# [Run 3/100] Seed: 1204431990
# ✅ Success! Clique size 28 found in 17.06s
#
# [Run 4/100] Seed: 1204449058
# ✅ Success! Clique size 28 found in 84.66s
#
# [Run 5/100] Seed: 1204533746
# ✅ Success! Clique size 28 found in 148.87s
#
# [Run 6/100] Seed: 1204682636
# ✅ Success! Clique size 28 found in 297.09s
#
# [Run 7/100] Seed: 1204979752
# ❌ Failed to reach 28 in this run.
#
# [Run 8/100] Seed: 1205338808
# ✅ Success! Clique size 28 found in 26.37s
#
# [Run 9/100] Seed: 1205365198
# ✅ Success! Clique size 28 found in 117.59s
#
# [Run 10/100] Seed: 1205482803
# ✅ Success! Clique size 28 found in 134.35s
#
# [Run 11/100] Seed: 1205617176
# ✅ Success! Clique size 28 found in 21.87s
#
# [Run 12/100] Seed: 1205639064
# ✅ Success! Clique size 28 found in 292.93s
#
# [Run 13/100] Seed: 1205932011
# ✅ Success! Clique size 28 found in 12.79s
#
# [Run 14/100] Seed: 1205944813
# ✅ Success! Clique size 28 found in 104.87s
#
# [Run 15/100] Seed: 1206049720
# ✅ Success! Clique size 28 found in 178.52s
#
# [Run 16/100] Seed: 1206228276
# ✅ Success! Clique size 28 found in 44.44s
#
# [Run 17/100] Seed: 1206272729
# ✅ Success! Clique size 28 found in 44.46s
#
# [Run 18/100] Seed: 1206317207
# ✅ Success! Clique size 28 found in 271.83s
#
# [Run 19/100] Seed: 1206589061
# ✅ Success! Clique size 28 found in 27.85s
#
# [Run 20/100] Seed: 1206616934
# ✅ Success! Clique size 28 found in 130.45s
#
# [Run 21/100] Seed: 1206747411
# ✅ Success! Clique size 28 found in 54.05s
#
# [Run 22/100] Seed: 1206801481
# ✅ Success! Clique size 28 found in 97.84s
#
# [Run 23/100] Seed: 1206899354
# ✅ Success! Clique size 28 found in 333.97s
#
# [Run 24/100] Seed: 1207233339
# ✅ Success! Clique size 28 found in 80.22s
#
# [Run 25/100] Seed: 1207313575
# ✅ Success! Clique size 28 found in 20.03s
#
# [Run 26/100] Seed: 1207333634
# ✅ Success! Clique size 28 found in 13.14s
#
# [Run 27/100] Seed: 1207346792
# ✅ Success! Clique size 28 found in 21.03s
#
# [Run 28/100] Seed: 1207367844
# ❌ Failed to reach 28 in this run.
#
# [Run 29/100] Seed: 1207726990
# ✅ Success! Clique size 28 found in 16.37s
#
# [Run 30/100] Seed: 1207743372
# ✅ Success! Clique size 28 found in 97.66s
#
# [Run 31/100] Seed: 1207841059
# ✅ Success! Clique size 28 found in 283.92s
#
# [Run 32/100] Seed: 1208124991
# ✅ Success! Clique size 28 found in 124.88s
#
# [Run 33/100] Seed: 1208249902
# ✅ Success! Clique size 28 found in 170.14s
#
# [Run 34/100] Seed: 1208420059
# ❌ Failed to reach 28 in this run.
#
# [Run 35/100] Seed: 1208778230
# ✅ Success! Clique size 28 found in 67.51s
#
# [Run 36/100] Seed: 1208845762
# ✅ Success! Clique size 28 found in 197.61s
#
# [Run 37/100] Seed: 1209043388
# ✅ Success! Clique size 28 found in 56.39s
#
# [Run 38/100] Seed: 1209099794
# ✅ Success! Clique size 28 found in 6.65s
#
# [Run 39/100] Seed: 1209106464
# ✅ Success! Clique size 28 found in 44.69s
#
# [Run 40/100] Seed: 1209151169
# ✅ Success! Clique size 28 found in 118.95s
#
# [Run 41/100] Seed: 1209270133
# ✅ Success! Clique size 28 found in 17.95s
#
# [Run 42/100] Seed: 1209288102
# ✅ Success! Clique size 28 found in 322.18s
#
# [Run 43/100] Seed: 1209610293
# ✅ Success! Clique size 28 found in 140.69s
#
# [Run 44/100] Seed: 1209751003
# ✅ Success! Clique size 28 found in 29.77s
#
# [Run 45/100] Seed: 1209780808
# ✅ Success! Clique size 28 found in 196.89s
#
# [Run 46/100] Seed: 1209977739
# ✅ Success! Clique size 28 found in 15.49s
#
# [Run 47/100] Seed: 1209993261
# ❌ Failed to reach 28 in this run.
#
# [Run 48/100] Seed: 1210347449
# ✅ Success! Clique size 28 found in 159.14s
#
# [Run 49/100] Seed: 1210506605
# ✅ Success! Clique size 28 found in 216.94s
#
# [Run 50/100] Seed: 1210723558
# ✅ Success! Clique size 28 found in 23.92s
#
# [Run 51/100] Seed: 1210747511
# ✅ Success! Clique size 28 found in 200.02s
#
# [Run 52/100] Seed: 1210947555
# ✅ Success! Clique size 28 found in 31.25s
#
# [Run 53/100] Seed: 1210978833
# ✅ Success! Clique size 28 found in 9.40s
#
# [Run 54/100] Seed: 1210988245
# ✅ Success! Clique size 28 found in 177.01s
#
# [Run 55/100] Seed: 1211165272
# ✅ Success! Clique size 28 found in 19.55s
#
# [Run 56/100] Seed: 1211184855
# ✅ Success! Clique size 28 found in 55.66s
#
# [Run 57/100] Seed: 1211240527
# ✅ Success! Clique size 28 found in 253.72s
#
# [Run 58/100] Seed: 1211494261
# ✅ Success! Clique size 28 found in 89.67s
#
# [Run 59/100] Seed: 1211583958
# ✅ Success! Clique size 28 found in 40.73s
#
# [Run 60/100] Seed: 1211624698
# ✅ Success! Clique size 28 found in 206.69s
#
# [Run 61/100] Seed: 1211831386
# ✅ Success! Clique size 28 found in 35.98s
#
# [Run 62/100] Seed: 1211867402
# ✅ Success! Clique size 28 found in 1.33s
#
# [Run 63/100] Seed: 1211868746
# ✅ Success! Clique size 28 found in 16.66s
#
# [Run 64/100] Seed: 1211885418
# ✅ Success! Clique size 28 found in 53.55s
#
# [Run 65/100] Seed: 1211938996
# ✅ Success! Clique size 28 found in 44.81s
#
# [Run 66/100] Seed: 1211983824
# ✅ Success! Clique size 28 found in 101.11s
#
# [Run 67/100] Seed: 1212084949
# ✅ Success! Clique size 28 found in 104.39s
#
# [Run 68/100] Seed: 1212189355
# ✅ Success! Clique size 28 found in 89.45s
#
# [Run 69/100] Seed: 1212278823
# ✅ Success! Clique size 28 found in 15.26s
#
# [Run 70/100] Seed: 1212294097
# ❌ Failed to reach 28 in this run.
#
# [Run 71/100] Seed: 1212654801
# ✅ Success! Clique size 28 found in 153.53s
#
# [Run 72/100] Seed: 1212808339
# ✅ Success! Clique size 28 found in 27.23s
#
# [Run 73/100] Seed: 1212835573
# ❌ Failed to reach 28 in this run.
#
# [Run 74/100] Seed: 1213195949
# ✅ Success! Clique size 28 found in 23.04s
#
# [Run 75/100] Seed: 1213219005
# ✅ Success! Clique size 28 found in 50.85s
#
# [Run 76/100] Seed: 1213269871
# ✅ Success! Clique size 28 found in 49.15s
#
# [Run 77/100] Seed: 1213319036
# ✅ Success! Clique size 28 found in 88.20s
#
# [Run 78/100] Seed: 1213407256
# ✅ Success! Clique size 28 found in 86.60s
#
# [Run 79/100] Seed: 1213493870
# ✅ Success! Clique size 28 found in 13.46s
#
# [Run 80/100] Seed: 1213507339
# ✅ Success! Clique size 28 found in 46.41s
#
# [Run 81/100] Seed: 1213553761
# ✅ Success! Clique size 28 found in 53.80s
#
# [Run 82/100] Seed: 1213607575
# ✅ Success! Clique size 28 found in 36.46s
#
# [Run 83/100] Seed: 1213644047
# ✅ Success! Clique size 28 found in 30.86s
#
# [Run 84/100] Seed: 1213674917
# ✅ Success! Clique size 28 found in 10.99s
#
# [Run 85/100] Seed: 1213685924
# ✅ Success! Clique size 28 found in 3.25s
#
# [Run 86/100] Seed: 1213689195
# ✅ Success! Clique size 28 found in 119.74s
#
# [Run 87/100] Seed: 1213808949
# ✅ Success! Clique size 28 found in 35.15s
#
# [Run 88/100] Seed: 1213844124
# ✅ Success! Clique size 28 found in 16.17s
#
# [Run 89/100] Seed: 1213860309
# ✅ Success! Clique size 28 found in 44.31s
#
# [Run 90/100] Seed: 1213904636
# ✅ Success! Clique size 28 found in 31.37s
#
# [Run 91/100] Seed: 1213936039
# ✅ Success! Clique size 28 found in 191.88s
#
# [Run 92/100] Seed: 1214127933
# ✅ Success! Clique size 28 found in 20.06s
#
# [Run 93/100] Seed: 1214148012
# ✅ Success! Clique size 28 found in 65.30s
#
# [Run 94/100] Seed: 1214213323
# ✅ Success! Clique size 28 found in 228.95s
#
# [Run 95/100] Seed: 1214442292
# ✅ Success! Clique size 28 found in 59.56s
#
# [Run 96/100] Seed: 1214501870
# ✅ Success! Clique size 28 found in 35.64s
#
# [Run 97/100] Seed: 1214537542
# ✅ Success! Clique size 28 found in 108.81s
#
# [Run 98/100] Seed: 1214646371
# ✅ Success! Clique size 28 found in 238.31s
#
# [Run 99/100] Seed: 1214884714
# ✅ Success! Clique size 28 found in 19.81s
#
# [Run 100/100] Seed: 1214904558
# ✅ Success! Clique size 28 found in 132.17s
#
# ============================================================
# BATCH COMPLETE: 94/100 SUCCESSFUL
# Total Time: 10652.88s
# Files saved in /statistics/ folder.
# ============================================================
